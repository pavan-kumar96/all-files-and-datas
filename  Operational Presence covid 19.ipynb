# %%
import pandas as pd

# %% [markdown]
# project name ;  Operational Presence

# %% [markdown]
# The Who does What Where is a core humanitarian dataset for coordination. This data contains operational presence of humanitarian partners in Somalia at Admin 2 level.

# %% [markdown]
# The Deyr rains (September-December) began in some parts of the country, according to the FAO-led Somalia Water and Land Information Management (SWALIM). Parts of the north eastern regions started to receive rains in mid-September and the last week of September also saw moderate rains in parts of the Gedo region in Jubaland.There is high risk of flooding along the Juba and Shabelle rivers given the onset of rains in Somalia and the Ethiopian highlands. Areas to watch along the Shabelle River include Beletweyne town and its environs where the river is currently near bank-full and other riverine towns in the Lower Shabelle region. Areas to watch along the Juba include Luuq and the mid-reaches of the river. The flood risk could be further exacerbated by weak river embankments and open river banks commonly seen in Somalia. New internal displacements has been increased from 11,000 families in August to 18,000 in September. Swift donor financial contributions to the Drought Impact Response Plan (DIRP) launched in May enabled aid agencies to scale up assistance currently reaching almost 2 million people per month in crisis and emergency phases of food insecurity.

# %%
mar_data = pd.read_csv('or_covid_datamar.csv')

# %%
mar_data.sample(1)
# Out:
#       CLUSTER ORGANIZATION IMPLEMENTING PARTNER PROGRAMME NAME  \
# 13950    WASH        READO                READO            NaN
#
#       ACTIVITY DESCRIPTION              DONOR MODALITY         \
# 13950   Shallow well REHAB  Emergency Reserve             NaN
#
#       CONDITIONALITY\n RESTRICTION\n TRANSFER VALUE (USD)\n  ...  X_COORD  \
# 13950              NaN           NaN                    NaN  ...  43.4667
#
#       Total # of INDIVIDUALS # of HOUSEHOLDS Women  Men Girls Boys  \
# 13950                    0.0             NaN   NaN  NaN   NaN  NaN
#
#       Additional Comments Unnamed: 29 Unnamed: 30
# 13950                 NaN         NaN         NaN
#
# [1 rows x 31 columns]

# %%
mar_data.shape
# Out:
# (15739, 31)

# %%
may_data = pd.read_excel('or_covid_datamay.xlsx')

# %%
may_data.head(5)
# Out:
#   Unnamed: 0    Unnamed: 1            Unnamed: 2  \
# 0        NaN           NaN                   NaN
# 1    Cluster  Organization  Implementing partner
# 2       CCCM         ACTED                  SADO
# 3       CCCM         ACTED                   NaN
# 4       CCCM         ACTED                   NaN
#
#                                           Unnamed: 3  \
# 0                                                NaN
# 1                                     Programme Name
# 2  Integrated WASH, Shelter, CCCM, Protection and...
# 3  Provision of Sustained CCCM Support for IDP Se...
# 4  Provision of Sustained CCCM Support for IDP Se...
#
#                                           Unnamed: 4     Unnamed: 5  \
# 0                                                NaN            NaN
# 1                               Activity description  Activity type
# 2  CCCM response comprised of coordination, monit...           Both
# 3  CCCM response comprised of coordination, capac...           Both
# 4  CCCM response comprised of coordination, capac...           Both
#
#   Unnamed: 6 Unnamed: 7                                            If cash  \
# 0        NaN        NaN                                     Conditionality
# 1      Donor   Modality  Pre-requisite: Are there any activities or obl...
# 2       OFDA        NaN                                                NaN
# 3        SHF        NaN                                                NaN
# 4        SHF        NaN                                                NaN
#
#                                           Unnamed: 9  ... Unnamed: 25  \
# 0                                        Restriction  ...         NaN
# 1  Utilization: What a transfer can be spent on a...  ...  Households
# 2                                                NaN  ...         NaN
# 3                                                NaN  ...         NaN
# 4                                                NaN  ...         NaN
#
#   Unnamed: 26 Unnamed: 27 Unnamed: 28 Unnamed: 29          Unnamed: 30  \
# 0         NaN         NaN         NaN         NaN                  NaN
# 1       Women         Men       Girls        Boys  Additional Comments
# 2         NaN         NaN         NaN         NaN                  NaN
# 3         NaN         NaN         NaN         NaN                  NaN
# 4         NaN         NaN         NaN         NaN                  NaN
#
#   Unnamed: 31 Unnamed: 32 Unnamed: 33 Unnamed: 34
# 0         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN
#
# [5 rows x 35 columns]
