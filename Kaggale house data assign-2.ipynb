# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data_train = pd.read_csv("data_train.csv")

# %%
data_train_cat = data_train.select_dtypes(include =  ["object"])

# %%
data_train_num = data_train.select_dtypes(exclude =  ["object"])

# %%
from sklearn.preprocessing import LabelEncoder

# %%
data_train_num
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0        1          60         65.0     8450            7            5
# 1        2          20         80.0     9600            6            8
# 2        3          60         68.0    11250            7            5
# 3        4          70         60.0     9550            7            5
# 4        5          60         84.0    14260            8            5
# ...    ...         ...          ...      ...          ...          ...
# 1455  1456          60         62.0     7917            6            5
# 1456  1457          20         85.0    13175            6            6
# 1457  1458          70         66.0     9042            7            9
# 1458  1459          20         68.0     9717            5            6
# 1459  1460          20         75.0     9937            5            6
#
#       YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  WoodDeckSF  \
# ...

# %%
data_train_cat
# Out:
#      MSZoning Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 0          RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1          RL   Pave   NaN      Reg         Lvl    AllPub       FR2       Gtl
# 2          RL   Pave   NaN      IR1         Lvl    AllPub    Inside       Gtl
# 3          RL   Pave   NaN      IR1         Lvl    AllPub    Corner       Gtl
# 4          RL   Pave   NaN      IR1         Lvl    AllPub       FR2       Gtl
# ...       ...    ...   ...      ...         ...       ...       ...       ...
# 1455       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1456       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1457       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1458       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1459       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
#
# ...

# %%
data_train_cat.sample(1)
# Out:
#     MSZoning Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 415       RL   Pave   NaN      IR1         Lvl    AllPub    Inside       Gtl
#
#     Neighborhood Condition1  ... GarageType GarageFinish GarageQual  \
# 415      Gilbert       Norm  ...     Attchd          Fin         TA
#
#     GarageCond PavedDrive PoolQC Fence MiscFeature SaleType SaleCondition
# 415         TA          Y    NaN   NaN         NaN      New       Partial
#
# [1 rows x 43 columns]

# %%
data_train.Id.isna().sum()
# Out:
# 0

# %%
cat = []
for col in data_train.columns:
    if data_train[col].isna().sum() > 500:
        cat.append(col)
print(cat)
# Out:
# ['Alley', 'FireplaceQu', 'PoolQC', 'Fence', 'MiscFeature']

# %%
data_train.drop(columns = cat, axis = 1, inplace = True)

# %% [markdown]
# ### Handling the missing values:
# two types  i.e is by replacing with mean value.

# %%
if data_train.Street.dtype == 'O':
    print(True)
# Out:
# True

# %%
data_train.OverallQual.dtype == 'int64'
#     print(True)
# Out:
# True

# %%
for col in missing_columns:
    if data_train[col].dtype == 'O':
        data_train[col].fillna(data_train[col].value_counts().sort_values().index[-1], inplace = True)
    else:
         data_train[col].fillna(np.round(data_train[col].mean(),0), inplace = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-25109a317d69> in <module>
# ----> 1 for col in missing_columns:
#       2     if data_train[col].dtype == 'O':
#       3         data_train[col].fillna(data_train[col].value_counts().sort_values().index[-1], inplace = True)
#       4     else:
#       5          data_train[col].fillna(np.round(data_train[col].mean(),0), inplace = True)
#
# NameError: name 'missing_columns' is not defined

# %% [markdown]
# ### Separating the category and integer values :

# %%
data_train_cat = data_train.select_dtypes(include =  ["object"])

# %%
missing_columns = []
for col in data_train.columns:
    if data_train[col].isna().sum() > 0:
        missing_columns.append(col)
# print(missing_columns)
# missing_data = data_train[[missing_columns]]

# %% [markdown]
# ### Identifying the cat columns and int columns

# %%
missing_columns

# %%
from sklearn.preprocessing import LabelEncoder

# %%
# set = {}
for col in data_train_cat.columns:
    le = LabelEncoder()
#     set[col] = le.fit(data_train_cat[col])
    data_train[col+"_num"] = le.fit_transform(data_train_cat[col])
#     print(col)

# %%
new_train_data = data_train.select_dtypes(exclude = ['object'])

# %%
trainX = new_train_data.drop(columns = ['SalePrice'])

# %%
trainY = new_train_data.SalePrice

# %%
data_test = pd.read_csv('data_test.csv')

# %%
cat = []
for col in data_test.columns:
    if data_test[col].isna().sum() > 500:
        cat.append(col)
print(cat)

# %%
data_test.drop(columns = cat, axis = 1, inplace = True)

# %%
missing_column = []
for col in data_test.columns:
    if data_test[col].isna().sum() > 0:
        missing_column.append(col)
# print(missing_columns)
# missing_data = data_train[[missing_columns]]

# %%
for col in missing_column:
    if data_test[col].dtype == 'O':
        data_test[col].fillna(data_test[col].value_counts().sort_values().index[-1], inplace = True)
    else:
         data_test[col].fillna(np.round(data_test[col].mean(),0), inplace = True)

# %%
data_test_cat = data_test.select_dtypes(include =  ["object"])

# %%
for col in data_test_cat.columns:
    lr = LabelEncoder()
#     set[col] = le.fit(data_train_cat[col])
    data_test[col+"_num"] = lr.fit_transform(data_test_cat[col])
#     print(col)

# %%
testX = data_test.select_dtypes(exclude= ['object'])

# %%
from xgboost import XGBRegressor

# %%
model = XGBRegressor()
model.fit(trainX,trainY)

# %%
testY = model.predict(testX)
testY

# %%
from sklearn.metrics import r2_score

# %%
from sklearn.metrics import median_absolute_error

# %%
len(data_test)

# %%
trainY.dtype

# %%
r2_score(trainY[:-1],testY)

# %%
r2_score(testY,trainY[:-1])

# %%
median_absolute_error(testY,trainY[:-1])

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data_train.plot.scatter(x= 'GrLivArea', y = 'SalePrice')
